# %%
t=6,7,8
type(t)
# Out:
# tuple

# %%
s={}
type(s)
# Out:
# dict

# %%
l=[9,0,67,0,8,8]
s=set(l)
s
# Out:
# {0, 8, 9, 67}

# %%
s={89,90,6,'p',78888888,4556,9}
s
# Out:
# {4556, 6, 78888888, 89, 9, 90, 'p'}

# %%
s={9,9,9}
s.add(90)
s
# Out:
# {9, 90}

# %%
s={6,7,8}
s.update([7,78])
s
# Out:
# {6, 7, 8, 78}
